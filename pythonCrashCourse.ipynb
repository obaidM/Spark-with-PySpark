# %%
mystr =  "this X is a string"
mystr

# %%
mystr.capitalize() # only first letter is capitalized

# %%
mystr

# %%
ystr = "obie"
zstr = "play chess"
print("my name is {} who likes to {}".format(ystr,zstr))

# %%
mylist = ['a','b','c','d','e','f']
mylist[4]  ## remember it starts from 0
mylist[1] = 'BBB'  ## its amended
mylist

# %%
mylist.append('GGG')
mylist.append(['x','y','z'])
mylist

# %%
mylist[7][2]  ## that is how you address in a multiple list

# %%
## dictionaries are very important in python. 
d ={'key1':'val1','key2':'val2','key3':'val3'}
print(d['key3'])

# %%
a=6
if a==6:
  print(mylist)
else:
  print(d)

# %%
for i in mylist:
  print(i)

# %%
for item in d:
  print(item)

# %%
myset = [1,2,"GGG",4,5.55,"pak","ind","USA",6,88]

# %%
for iter in myset[0:5]:
  print(iter)   ### iter stands for iteration

# %%
i = 0 
while i<7:
  print("i value is {}".format(i))
  i= i+1

# %%
## list comprehesnion 
x = [1,2,2,3,5]
[i**3 for i in x]

# %%
def func111(nn):
    print("my name is {}".format(nn))

# %%
func111('dog')

# %%
func111('obaid Masih')

# %%
###### 
## LAMBDA, VERY Useful in python
#######

# %%
lambda var: var**2

# %%
newstr = " hello my name is OBAID"
newstr.lower()

# %%
newstr.split()

# %%
tweet = " hello #Python"
tweet.lower().split("#")[-1]
